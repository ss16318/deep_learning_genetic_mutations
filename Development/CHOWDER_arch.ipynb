# %% [markdown]
# # CHOWDER

# %% [markdown]
# ## Imports

# %%
# !pip install torchmetrics
# Out:
# Collecting torchmetrics
#   Downloading torchmetrics-1.2.0-py3-none-any.whl (805 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 805.2/805.2 kB 11.0 MB/s eta 0:00:00
# Requirement already satisfied: numpy>1.20.0 in /usr/local/lib/python3.10/dist-packages (from torchmetrics) (1.23.5)
# Requirement already satisfied: torch>=1.8.1 in /usr/local/lib/python3.10/dist-packages (from torchmetrics) (2.1.0+cu118)
# Collecting lightning-utilities>=0.8.0 (from torchmetrics)
#   Downloading lightning_utilities-0.9.0-py3-none-any.whl (23 kB)
# Requirement already satisfied: packaging>=17.1 in /usr/local/lib/python3.10/dist-packages (from lightning-utilities>=0.8.0->torchmetrics) (23.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from lightning-utilities>=0.8.0->torchmetrics) (4.5.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.1->torchmetrics) (3.13.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.1->torchmetrics) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.1->torchmetrics) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.1->torchmetrics) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.1->torchmetrics) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.1->torchmetrics) (2.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.8.1->torchmetrics) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.8.1->torchmetrics) (1.3.0)
# Installing collected packages: lightning-utilities, torchmetrics
# Successfully installed lightning-utilities-0.9.0 torchmetrics-1.2.0

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import torch
from torch.utils.data import Dataset, DataLoader, TensorDataset, ConcatDataset
import torch.nn as nn
import torch.optim as optim
import torchmetrics

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Load Data

# %%
processed_data_path = '/content/drive/My Drive/Breast_Cancer_Detection/Processed_Data/'

X_dev = np.load(processed_data_path + 'X_dev.npy')
y_dev = np.load(processed_data_path + 'y_dev.npy')

X_test = np.load(processed_data_path + 'X_test.npy')

# %% [markdown]
# ## Split Data

# %%
X_train, X_val, y_train, y_val = train_test_split(X_dev, y_dev, test_size=0.15, stratify=y_dev, random_state=42)

# %% [markdown]
# ## Standardize Data

# %%
def X_standardize(X_train, X_val, X_test):

    feature_mean = np.mean(X_train)
    feature_std = np.std(X_train)

    X_train_scaled = (X_train - feature_mean) / feature_std
    X_val_scaled = (X_val - feature_mean) / feature_std
    X_test_scaled = (X_test - feature_mean) / feature_std

    return X_train_scaled, X_val_scaled, X_test_scaled

# %%
X_train_scaled, X_val_scaled, X_test_scaled = X_standardize(X_train, X_val, X_test)

# %% [markdown]
# ## Convert to Tensor

# %%
X_train_tensor = torch.Tensor(X_train_scaled)
X_val_tensor = torch.Tensor(X_val_scaled)
X_test_tensor = torch.Tensor(X_test_scaled)

# %%
# Delete redundant variables to free up memory
del X_train_scaled
del X_val_scaled
del X_test_scaled
del X_train
del X_val
del X_test
del X_dev

# %% [markdown]
# ## CHOWDER Model

# %%
class CHOWDER(nn.Module):

    def __init__(self):
        super(CHOWDER, self).__init__()

        # Convolutional layer
        self.conv = nn.Conv1d(in_channels=1, out_channels=1, kernel_size=2048, stride=2048)

        self.fc1 = nn.Linear(4, 1)

        self.init_weights()

    def init_weights(self):

        # Set std to the square root of the number of edges
        std_conv = 2048**(-0.5)
        # Initialize weights with random normal values for the convolutional layer
        nn.init.normal_(self.conv.weight, mean=0.0, std=std_conv)
        nn.init.constant_(self.conv.bias, 0)


    def forward(self, x):

        ## CONVOLUTION LAYER
        conv_output = self.conv(x)

        # Calculate L2-norm on weights in the convolutional layer
        l2_reg = 0.0
        for param in self.conv.parameters():
            l2_reg += torch.sum(param ** 2)

        ## MINMAX LAYER

        # Sort each row of the conv layer (each row is a sample)
        sorted_output, _ = torch.sort(conv_output, dim=2)

        # Number of top instances and negative evidence
        R = 2

        # Select the first two and last two sorted outputs
        selected_output = sorted_output[:, :, :R]
        a0 = torch.cat((selected_output, sorted_output[:, :, -R:]), dim=2)

        a0 = a0.squeeze()

        z1 = self.fc1(a0)

        output = torch.sigmoid(z1)

        return output, l2_reg

# %%
demo_model = CHOWDER()

demo_model
# Out:
# CHOWDER(
#   (conv): Conv1d(1, 1, kernel_size=(2048,), stride=(2048,))
#   (fc1): Linear(in_features=4, out_features=1, bias=True)
# )

# %% [markdown]
# ## Setup Hyperparameters and Data Loader

# %%
# Define hyperparameters
BATCH_SIZE = 10
LR = 0.001
EPOCHS = 20
NUM_ENSEMBLE_MODELS = 10

# %%
class CustomDataset(Dataset):

    def __init__(self, data_tensor, target_tensor):
        self.data = data_tensor
        self.target = target_tensor

    def __getitem__(self, index):
        x = self.data[index]
        y = self.target[index]
        return x, y

    def __len__(self):
        return len(self.data)

# Create custom datasets
train_dataset = CustomDataset(X_train_tensor, torch.Tensor(y_train))
val_dataset = CustomDataset(X_val_tensor, torch.Tensor(y_val))

# Create DataLoader
train_dl = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, drop_last=True)
val_dl = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=True, drop_last=True)

# %%
# Free Up Memory
del X_train_tensor
del X_val_tensor
del y_train
del y_val

# %% [markdown]
# ## Train Model and Validate

# %%
# Define loss function and optimizer
loss_function = nn.BCELoss()

# Create an ensemble of models
ensemble_models = []

for _ in range(NUM_ENSEMBLE_MODELS):

    # Initialize the model
    model = CHOWDER()

    # Define optimizer
    optimizer = optim.Adam(model.parameters(), lr=LR)
    ensemble_models.append((model, optimizer))

# Setup model counter
model_counter = 1

# Training and validation loops for each model in the ensemble
for model, optimizer in ensemble_models:

    print(f'\n ----- Model {model_counter} -----')
    model_counter += 1

    # Loop thorugh each epoch
    for epoch in range(EPOCHS):

        ## Training loop

        # Put model in train mode
        model.train()

        # Initialize loss, AUC and count
        total_loss = 0.0
        auroc_hist_train = 0.0
        total_count = 0.0

        # Train in batches
        for batch_x, batch_y in train_dl:

            batch_x_transformed = batch_x.unsqueeze(1)

            # Zero gradients
            optimizer.zero_grad()

            # Make predictions and get L2-norm from conv layer
            pred, weight_decay = model(batch_x_transformed)

            # Calculate loss
            batch_y = batch_y.view(-1, 1) # Reshape batch_y from (10) to (10,1)
            loss = loss_function(pred, batch_y) + (0.1*weight_decay)

            # Calculate gradients
            loss.backward()

            # Make step in gradient descent
            optimizer.step()

            # Add to loss counter for this epoch
            total_loss += loss.item() * len(batch_y)
            total_count += len(batch_y)

            # Calculate AUC for batch
            auroc_hist_train += torchmetrics.AUROC(task="binary")(pred, batch_y).item() * len(batch_y)

        # Calculate loss and AUC per sample
        train_average_loss = total_loss / total_count
        train_average_auc = auroc_hist_train/ total_count


        ## Validation loop

        # Put model in evaluation mode
        model.eval()

        # Fix gradients (only using model to predict)
        with torch.no_grad():

            # Initialize loss, AUC and count
            total_loss = 0.0
            auroc_hist_val = 0.0
            total_count = 0.0

            # Validate in batches
            for batch_x, batch_y in val_dl:

                batch_x_transformed = batch_x.unsqueeze(1)

                # Make predictions
                val_pred, _ = model(batch_x_transformed)

                # Calculate loss
                batch_y = batch_y.view(-1, 1) # Reshape batch_y from (10) to (10,1)
                loss = loss_function(val_pred, batch_y)

                # Add to loss for this epoch
                total_loss += loss.item() * len(batch_y)
                total_count += len(batch_y)

                # Calculate AUC for batch
                auroc_hist_val += torchmetrics.AUROC(task="binary")(val_pred, batch_y).item() * len(batch_y)

        # Calculate loss and AUC per sample
        val_average_loss = total_loss / total_count
        val_average_auc =  auroc_hist_val / total_count

        # Print results from each epoch
        print(f"Epoch [{epoch+1}/{EPOCHS}] - Train Loss: {train_average_loss:.4f} Train AUC Score: {train_average_auc:.4f} \
        Val Loss: {val_average_loss:.4f} Val AUC Score: {val_average_auc:.4f}")
# Out:
#  ----- Model 1 -----
# Epoch [1/20] - Train Loss: 0.7720 Train AUC Score: 0.5092         Val Loss: 0.6780 Val AUC Score: 0.5018
# Epoch [2/20] - Train Loss: 0.7286 Train AUC Score: 0.6464         Val Loss: 0.6797 Val AUC Score: 0.5982
# Epoch [3/20] - Train Loss: 0.7018 Train AUC Score: 0.6774         Val Loss: 0.7030 Val AUC Score: 0.5179
# Epoch [4/20] - Train Loss: 0.6791 Train AUC Score: 0.7325         Val Loss: 0.6510 Val AUC Score: 0.6025
# /usr/local/lib/python3.10/dist-packages/torchmetrics/utilities/prints.py:43: UserWarning: No positive samples in targets, true positive value should be meaningless. Returning zero tensor in true positive score
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Epoch [5/20] - Train Loss: 0.6701 Train AUC Score: 0.7145         Val Loss: 0.6691 Val AUC Score: 0.4653
# Epoch [6/20] - Train Loss: 0.6432 Train AUC Score: 0.8026         Val Loss: 0.6573 Val AUC Score: 0.5115
# Epoch [7/20] - Train Loss: 0.6385 Train AUC Score: 0.8190         Val Loss: 0.6492 Val AUC Score: 0.6042
# Epoch [8/20] - Train Loss: 0.6282 Train AUC Score: 0.7891         Val Loss: 0.7100 Val AUC Score: 0.5536
# Epoch [9/20] - Train Loss: 0.6080 Train AUC Score: 0.8286         Val Loss: 0.6558 Val AUC Score: 0.4757
# Epoch [10/20] - Train Loss: 0.5971 Train AUC Score: 0.8558         Val Loss: 0.7126 Val AUC Score: 0.5233
# Epoch [11/20] - Train Loss: 0.5801 Train AUC Score: 0.8420         Val Loss: 0.7018 Val AUC Score: 0.4339
# Epoch [12/20] - Train Loss: 0.5776 Train AUC Score: 0.8680         Val Loss: 0.6700 Val AUC Score: 0.6169
# Epoch [13/20] - Train Loss: 0.5608 Train AUC Score: 0.9216         Val Loss: 0.7174 Val AUC Score: 0.5037
# Epoch [14/20] - Train Loss: 0.5519 Train AUC Score: 0.8980         Val Loss: 0.6770 Val AUC Score: 0.5521
# Epoch [15/20] - Train Loss: 0.5492 Train AUC Score: 0.9118         Val Loss: 0.7242 Val AUC Score: 0.5125
# Epoch [16/20] - Train Loss: 0.5421 Train AUC Score: 0.9194         Val Loss: 0.7161 Val AUC Score: 0.4836
# Epoch [17/20] - Train Loss: 0.5387 Train AUC Score: 0.9081         Val Loss: 0.7401 Val AUC Score: 0.4151
# Epoch [18/20] - Train Loss: 0.5330 Train AUC Score: 0.8849         Val Loss: 0.7113 Val AUC Score: 0.3854
# Epoch [19/20] - Train Loss: 0.5203 Train AUC Score: 0.9217         Val Loss: 0.6646 Val AUC Score: 0.5993
# Epoch [20/20] - Train Loss: 0.5219 Train AUC Score: 0.9189         Val Loss: 0.6935 Val AUC Score: 0.5069
#
#  ----- Model 2 -----
# Epoch [1/20] - Train Loss: 0.7861 Train AUC Score: 0.3846         Val Loss: 0.6385 Val AUC Score: 0.6198
# Epoch [2/20] - Train Loss: 0.7299 Train AUC Score: 0.5661         Val Loss: 0.6364 Val AUC Score: 0.6741
# Epoch [3/20] - Train Loss: 0.7076 Train AUC Score: 0.6758         Val Loss: 0.6318 Val AUC Score: 0.6533
# Epoch [4/20] - Train Loss: 0.6830 Train AUC Score: 0.7352         Val Loss: 0.6375 Val AUC Score: 0.6406
# Epoch [5/20] - Train Loss: 0.6718 Train AUC Score: 0.7826         Val Loss: 0.6403 Val AUC Score: 0.5104
# Epoch [6/20] - Train Loss: 0.6560 Train AUC Score: 0.7770         Val Loss: 0.6582 Val AUC Score: 0.7500
# Epoch [7/20] - Train Loss: 0.6394 Train AUC Score: 0.8161         Val Loss: 0.6769 Val AUC Score: 0.4925
# Epoch [8/20] - Train Loss: 0.6225 Train AUC Score: 0.8622         Val Loss: 0.6302 Val AUC Score: 0.6659
# Epoch [9/20] - Train Loss: 0.6191 Train AUC Score: 0.8617         Val Loss: 0.6487 Val AUC Score: 0.6228
# Epoch [10/20] - Train Loss: 0.6071 Train AUC Score: 0.8524         Val Loss: 0.6080 Val AUC Score: 0.6921
# Epoch [11/20] - Train Loss: 0.5822 Train AUC Score: 0.8840         Val Loss: 0.6407 Val AUC Score: 0.4921
# Epoch [12/20] - Train Loss: 0.5771 Train AUC Score: 0.9052         Val Loss: 0.6339 Val AUC Score: 0.7396
# Epoch [13/20] - Train Loss: 0.5693 Train AUC Score: 0.9239         Val Loss: 0.6608 Val AUC Score: 0.6752
# Epoch [14/20] - Train Loss: 0.5567 Train AUC Score: 0.9266         Val Loss: 0.5776 Val AUC Score: 0.7292
# Epoch [15/20] - Train Loss: 0.5407 Train AUC Score: 0.9151         Val Loss: 0.6959 Val AUC Score: 0.5951
# Epoch [16/20] - Train Loss: 0.5463 Train AUC Score: 0.9311         Val Loss: 0.6414 Val AUC Score: 0.7250
# Epoch [17/20] - Train Loss: 0.5366 Train AUC Score: 0.9394         Val Loss: 0.6496 Val AUC Score: 0.6842
# Epoch [18/20] - Train Loss: 0.5210 Train AUC Score: 0.9441         Val Loss: 0.6618 Val AUC Score: 0.6771
# Epoch [19/20] - Train Loss: 0.5167 Train AUC Score: 0.9404         Val Loss: 0.6326 Val AUC Score: 0.7937
# Epoch [20/20] - Train Loss: 0.5047 Train AUC Score: 0.9581         Val Loss: 0.6673 Val AUC Score: 0.7169
#
#  ----- Model 3 -----
# Epoch [1/20] - Train Loss: 0.7821 Train AUC Score: 0.4853         Val Loss: 0.6617 Val AUC Score: 0.5315
# Epoch [2/20] - Train Loss: 0.7034 Train AUC Score: 0.7484         Val Loss: 0.5971 Val AUC Score: 0.7118
# Epoch [3/20] - Train Loss: 0.6506 Train AUC Score: 0.8001         Val Loss: 0.6806 Val AUC Score: 0.6027
# Epoch [4/20] - Train Loss: 0.6092 Train AUC Score: 0.8050         Val Loss: 0.6148 Val AUC Score: 0.6107
# Epoch [5/20] - Train Loss: 0.5702 Train AUC Score: 0.8941         Val Loss: 0.6462 Val AUC Score: 0.5479
# Epoch [6/20] - Train Loss: 0.5548 Train AUC Score: 0.8839         Val Loss: 0.6478 Val AUC Score: 0.5683
# Epoch [7/20] - Train Loss: 0.5236 Train AUC Score: 0.8816         Val Loss: 0.6711 Val AUC Score: 0.5977
# Epoch [8/20] - Train Loss: 0.5040 Train AUC Score: 0.8792         Val Loss: 0.6925 Val AUC Score: 0.6064
# Epoch [9/20] - Train Loss: 0.4798 Train AUC Score: 0.9441         Val Loss: 0.7350 Val AUC Score: 0.4742
# Epoch [10/20] - Train Loss: 0.4802 Train AUC Score: 0.9444         Val Loss: 0.7227 Val AUC Score: 0.5714
# Epoch [11/20] - Train Loss: 0.4426 Train AUC Score: 0.8885         Val Loss: 0.7810 Val AUC Score: 0.4365
# Epoch [12/20] - Train Loss: 0.4340 Train AUC Score: 0.9413         Val Loss: 0.7176 Val AUC Score: 0.5175
# Epoch [13/20] - Train Loss: 0.4214 Train AUC Score: 0.9533         Val Loss: 0.7816 Val AUC Score: 0.3745
# Epoch [14/20] - Train Loss: 0.4313 Train AUC Score: 0.9619         Val Loss: 0.7557 Val AUC Score: 0.4910
# Epoch [15/20] - Train Loss: 0.4082 Train AUC Score: 0.9755         Val Loss: 0.7120 Val AUC Score: 0.5670
# Epoch [16/20] - Train Loss: 0.3880 Train AUC Score: 0.9701         Val Loss: 0.7693 Val AUC Score: 0.5271
# Epoch [17/20] - Train Loss: 0.4197 Train AUC Score: 0.9760         Val Loss: 0.8222 Val AUC Score: 0.5789
# Epoch [18/20] - Train Loss: 0.3885 Train AUC Score: 0.9730         Val Loss: 0.7578 Val AUC Score: 0.5598
# Epoch [19/20] - Train Loss: 0.3683 Train AUC Score: 0.9446         Val Loss: 0.7043 Val AUC Score: 0.6533
# Epoch [20/20] - Train Loss: 0.3570 Train AUC Score: 0.9790         Val Loss: 0.8085 Val AUC Score: 0.5000
#
#  ----- Model 4 -----
# Epoch [1/20] - Train Loss: 0.7606 Train AUC Score: 0.5579         Val Loss: 0.6355 Val AUC Score: 0.6235
# Epoch [2/20] - Train Loss: 0.7042 Train AUC Score: 0.6902         Val Loss: 0.6143 Val AUC Score: 0.8171
# Epoch [3/20] - Train Loss: 0.6779 Train AUC Score: 0.7298         Val Loss: 0.6416 Val AUC Score: 0.6845
# Epoch [4/20] - Train Loss: 0.6332 Train AUC Score: 0.8199         Val Loss: 0.6371 Val AUC Score: 0.6927
# Epoch [5/20] - Train Loss: 0.5838 Train AUC Score: 0.8732         Val Loss: 0.6524 Val AUC Score: 0.6942
# Epoch [6/20] - Train Loss: 0.5592 Train AUC Score: 0.8971         Val Loss: 0.6294 Val AUC Score: 0.7493
# Epoch [7/20] - Train Loss: 0.5378 Train AUC Score: 0.8314         Val Loss: 0.6530 Val AUC Score: 0.6250
# Epoch [8/20] - Train Loss: 0.5248 Train AUC Score: 0.9038         Val Loss: 0.6518 Val AUC Score: 0.7083
# Epoch [9/20] - Train Loss: 0.5073 Train AUC Score: 0.9314         Val Loss: 0.5750 Val AUC Score: 0.7485
# Epoch [10/20] - Train Loss: 0.4851 Train AUC Score: 0.9531         Val Loss: 0.5658 Val AUC Score: 0.7411
# Epoch [11/20] - Train Loss: 0.4901 Train AUC Score: 0.9347         Val Loss: 0.6707 Val AUC Score: 0.6599
# Epoch [12/20] - Train Loss: 0.4598 Train AUC Score: 0.9231         Val Loss: 0.7460 Val AUC Score: 0.6585
# Epoch [13/20] - Train Loss: 0.4552 Train AUC Score: 0.9619         Val Loss: 0.7450 Val AUC Score: 0.5779
# Epoch [14/20] - Train Loss: 0.4372 Train AUC Score: 0.9898         Val Loss: 0.7182 Val AUC Score: 0.5595
# Epoch [15/20] - Train Loss: 0.4166 Train AUC Score: 0.9686         Val Loss: 0.6271 Val AUC Score: 0.6611
# Epoch [16/20] - Train Loss: 0.4130 Train AUC Score: 0.9372         Val Loss: 0.6985 Val AUC Score: 0.5821
# Epoch [17/20] - Train Loss: 0.4117 Train AUC Score: 0.9758         Val Loss: 0.6786 Val AUC Score: 0.6358
# Epoch [18/20] - Train Loss: 0.3953 Train AUC Score: 0.9731         Val Loss: 0.7408 Val AUC Score: 0.6115
# Epoch [19/20] - Train Loss: 0.3874 Train AUC Score: 0.9868         Val Loss: 0.7226 Val AUC Score: 0.6235
# Epoch [20/20] - Train Loss: 0.3688 Train AUC Score: 0.9892         Val Loss: 0.7223 Val AUC Score: 0.6608
#
#  ----- Model 5 -----
# Epoch [1/20] - Train Loss: 0.8877 Train AUC Score: 0.5210         Val Loss: 0.6664 Val AUC Score: 0.7415
# Epoch [2/20] - Train Loss: 0.7270 Train AUC Score: 0.6720         Val Loss: 0.5999 Val AUC Score: 0.5655
# Epoch [3/20] - Train Loss: 0.6830 Train AUC Score: 0.8423         Val Loss: 0.6550 Val AUC Score: 0.6696
# Epoch [4/20] - Train Loss: 0.6507 Train AUC Score: 0.8049         Val Loss: 0.6000 Val AUC Score: 0.6900
# Epoch [5/20] - Train Loss: 0.6195 Train AUC Score: 0.8231         Val Loss: 0.6294 Val AUC Score: 0.6220
# Epoch [6/20] - Train Loss: 0.5942 Train AUC Score: 0.8781         Val Loss: 0.6667 Val AUC Score: 0.6093
# Epoch [7/20] - Train Loss: 0.5767 Train AUC Score: 0.9151         Val Loss: 0.6529 Val AUC Score: 0.6143
# Epoch [8/20] - Train Loss: 0.5578 Train AUC Score: 0.9442         Val Loss: 0.6823 Val AUC Score: 0.5693
# Epoch [9/20] - Train Loss: 0.5336 Train AUC Score: 0.9453         Val Loss: 0.6854 Val AUC Score: 0.6415
# Epoch [10/20] - Train Loss: 0.5165 Train AUC Score: 0.9573         Val Loss: 0.6519 Val AUC Score: 0.6235
# Epoch [11/20] - Train Loss: 0.5055 Train AUC Score: 0.9590         Val Loss: 0.7112 Val AUC Score: 0.6545
# Epoch [12/20] - Train Loss: 0.4816 Train AUC Score: 0.9771         Val Loss: 0.7452 Val AUC Score: 0.5357
# Epoch [13/20] - Train Loss: 0.4656 Train AUC Score: 0.9767         Val Loss: 0.7083 Val AUC Score: 0.6185
# Epoch [14/20] - Train Loss: 0.4547 Train AUC Score: 0.9765         Val Loss: 0.7761 Val AUC Score: 0.5521
# Epoch [15/20] - Train Loss: 0.4426 Train AUC Score: 0.9899         Val Loss: 0.7620 Val AUC Score: 0.5707
# Epoch [16/20] - Train Loss: 0.4258 Train AUC Score: 0.9329         Val Loss: 0.7706 Val AUC Score: 0.5559
# Epoch [17/20] - Train Loss: 0.4126 Train AUC Score: 0.9831         Val Loss: 0.7756 Val AUC Score: 0.5014
# Epoch [18/20] - Train Loss: 0.4071 Train AUC Score: 0.9930         Val Loss: 0.7945 Val AUC Score: 0.5975
# Epoch [19/20] - Train Loss: 0.3934 Train AUC Score: 0.9862         Val Loss: 0.8125 Val AUC Score: 0.4583
# Epoch [20/20] - Train Loss: 0.3775 Train AUC Score: 0.9885         Val Loss: 0.8255 Val AUC Score: 0.6657
#
#  ----- Model 6 -----
# Epoch [1/20] - Train Loss: 0.9501 Train AUC Score: 0.5472         Val Loss: 0.6868 Val AUC Score: 0.4327
# Epoch [2/20] - Train Loss: 0.7508 Train AUC Score: 0.5776         Val Loss: 0.6505 Val AUC Score: 0.5937
# Epoch [3/20] - Train Loss: 0.7129 Train AUC Score: 0.6869         Val Loss: 0.6605 Val AUC Score: 0.5563
# Epoch [4/20] - Train Loss: 0.6854 Train AUC Score: 0.7022         Val Loss: 0.6576 Val AUC Score: 0.5312
# Epoch [5/20] - Train Loss: 0.6638 Train AUC Score: 0.7615         Val Loss: 0.6707 Val AUC Score: 0.5659
# Epoch [6/20] - Train Loss: 0.6346 Train AUC Score: 0.8556         Val Loss: 0.6491 Val AUC Score: 0.5168
# Epoch [7/20] - Train Loss: 0.6084 Train AUC Score: 0.8834         Val Loss: 0.6303 Val AUC Score: 0.5124
# Epoch [8/20] - Train Loss: 0.6003 Train AUC Score: 0.8417         Val Loss: 0.6683 Val AUC Score: 0.3715
# Epoch [9/20] - Train Loss: 0.5787 Train AUC Score: 0.8917         Val Loss: 0.6588 Val AUC Score: 0.5595
# Epoch [10/20] - Train Loss: 0.5678 Train AUC Score: 0.9428         Val Loss: 0.6662 Val AUC Score: 0.5789
# Epoch [11/20] - Train Loss: 0.5528 Train AUC Score: 0.9289         Val Loss: 0.6728 Val AUC Score: 0.6310
# Epoch [12/20] - Train Loss: 0.5467 Train AUC Score: 0.9335         Val Loss: 0.6745 Val AUC Score: 0.5915
# Epoch [13/20] - Train Loss: 0.5208 Train AUC Score: 0.9372         Val Loss: 0.6859 Val AUC Score: 0.5246
# Epoch [14/20] - Train Loss: 0.5109 Train AUC Score: 0.9563         Val Loss: 0.6853 Val AUC Score: 0.5104
# Epoch [15/20] - Train Loss: 0.5038 Train AUC Score: 0.9694         Val Loss: 0.6591 Val AUC Score: 0.5848
# Epoch [16/20] - Train Loss: 0.4952 Train AUC Score: 0.9585         Val Loss: 0.6872 Val AUC Score: 0.6086
# Epoch [17/20] - Train Loss: 0.4818 Train AUC Score: 0.9290         Val Loss: 0.6464 Val AUC Score: 0.6012
# Epoch [18/20] - Train Loss: 0.4726 Train AUC Score: 0.8981         Val Loss: 0.6552 Val AUC Score: 0.6086
# Epoch [19/20] - Train Loss: 0.4538 Train AUC Score: 0.9366         Val Loss: 0.6400 Val AUC Score: 0.5342
# Epoch [20/20] - Train Loss: 0.4501 Train AUC Score: 0.9888         Val Loss: 0.6374 Val AUC Score: 0.7104
#
#  ----- Model 7 -----
# Epoch [1/20] - Train Loss: 0.7540 Train AUC Score: 0.5402         Val Loss: 0.6506 Val AUC Score: 0.7414
# Epoch [2/20] - Train Loss: 0.7134 Train AUC Score: 0.6607         Val Loss: 0.6177 Val AUC Score: 0.7002
# Epoch [3/20] - Train Loss: 0.6842 Train AUC Score: 0.7132         Val Loss: 0.6341 Val AUC Score: 0.5513
# Epoch [4/20] - Train Loss: 0.6649 Train AUC Score: 0.7688         Val Loss: 0.6257 Val AUC Score: 0.6021
# Epoch [5/20] - Train Loss: 0.6520 Train AUC Score: 0.7402         Val Loss: 0.6300 Val AUC Score: 0.6864
# Epoch [6/20] - Train Loss: 0.6371 Train AUC Score: 0.7910         Val Loss: 0.6401 Val AUC Score: 0.6849
# Epoch [7/20] - Train Loss: 0.6246 Train AUC Score: 0.7912         Val Loss: 0.6243 Val AUC Score: 0.6464
# Epoch [8/20] - Train Loss: 0.6015 Train AUC Score: 0.8501         Val Loss: 0.6019 Val AUC Score: 0.7217
# Epoch [9/20] - Train Loss: 0.6012 Train AUC Score: 0.8549         Val Loss: 0.5696 Val AUC Score: 0.7092
# Epoch [10/20] - Train Loss: 0.5876 Train AUC Score: 0.8728         Val Loss: 0.6203 Val AUC Score: 0.7039
# Epoch [11/20] - Train Loss: 0.5665 Train AUC Score: 0.8411         Val Loss: 0.6326 Val AUC Score: 0.6860
# Epoch [12/20] - Train Loss: 0.5709 Train AUC Score: 0.8510         Val Loss: 0.5832 Val AUC Score: 0.7554
# Epoch [13/20] - Train Loss: 0.5596 Train AUC Score: 0.8997         Val Loss: 0.5936 Val AUC Score: 0.6994
# Epoch [14/20] - Train Loss: 0.5377 Train AUC Score: 0.9228         Val Loss: 0.5544 Val AUC Score: 0.7708
# Epoch [15/20] - Train Loss: 0.5260 Train AUC Score: 0.7893         Val Loss: 0.5544 Val AUC Score: 0.8073
# Epoch [16/20] - Train Loss: 0.5089 Train AUC Score: 0.9233         Val Loss: 0.5701 Val AUC Score: 0.7619
# Epoch [17/20] - Train Loss: 0.5058 Train AUC Score: 0.9112         Val Loss: 0.5964 Val AUC Score: 0.7933
# Epoch [18/20] - Train Loss: 0.4942 Train AUC Score: 0.8789         Val Loss: 0.6379 Val AUC Score: 0.6284
# Epoch [19/20] - Train Loss: 0.4922 Train AUC Score: 0.8823         Val Loss: 0.5879 Val AUC Score: 0.7054
# Epoch [20/20] - Train Loss: 0.4786 Train AUC Score: 0.9160         Val Loss: 0.6296 Val AUC Score: 0.7054
#
#  ----- Model 8 -----
# Epoch [1/20] - Train Loss: 2.1533 Train AUC Score: 0.5001         Val Loss: 1.4322 Val AUC Score: 0.4862
# Epoch [2/20] - Train Loss: 1.4270 Train AUC Score: 0.5671         Val Loss: 1.2004 Val AUC Score: 0.6570
# Epoch [3/20] - Train Loss: 1.1563 Train AUC Score: 0.5986         Val Loss: 0.9991 Val AUC Score: 0.4687
# Epoch [4/20] - Train Loss: 1.0099 Train AUC Score: 0.6236         Val Loss: 0.9638 Val AUC Score: 0.5571
# Epoch [5/20] - Train Loss: 0.9012 Train AUC Score: 0.6228         Val Loss: 0.8353 Val AUC Score: 0.4516
# Epoch [6/20] - Train Loss: 0.7828 Train AUC Score: 0.6813         Val Loss: 0.7177 Val AUC Score: 0.3732
# Epoch [7/20] - Train Loss: 0.7182 Train AUC Score: 0.6607         Val Loss: 0.7289 Val AUC Score: 0.3514
# Epoch [8/20] - Train Loss: 0.6738 Train AUC Score: 0.7976         Val Loss: 0.7332 Val AUC Score: 0.3482
# Epoch [9/20] - Train Loss: 0.6501 Train AUC Score: 0.7949         Val Loss: 0.7368 Val AUC Score: 0.3467
# Epoch [10/20] - Train Loss: 0.6259 Train AUC Score: 0.8442         Val Loss: 0.7773 Val AUC Score: 0.2421
# Epoch [11/20] - Train Loss: 0.5877 Train AUC Score: 0.8531         Val Loss: 0.7868 Val AUC Score: 0.2485
# Epoch [12/20] - Train Loss: 0.5700 Train AUC Score: 0.9367         Val Loss: 0.8347 Val AUC Score: 0.1918
# Epoch [13/20] - Train Loss: 0.5409 Train AUC Score: 0.9454         Val Loss: 0.8183 Val AUC Score: 0.2398
# Epoch [14/20] - Train Loss: 0.5216 Train AUC Score: 0.9643         Val Loss: 0.7746 Val AUC Score: 0.2505
# Epoch [15/20] - Train Loss: 0.5070 Train AUC Score: 0.9587         Val Loss: 0.8305 Val AUC Score: 0.2144
# Epoch [16/20] - Train Loss: 0.4895 Train AUC Score: 0.9694         Val Loss: 0.8731 Val AUC Score: 0.1726
# Epoch [17/20] - Train Loss: 0.4813 Train AUC Score: 0.9650         Val Loss: 0.8197 Val AUC Score: 0.2366
# Epoch [18/20] - Train Loss: 0.4662 Train AUC Score: 0.9722         Val Loss: 0.8709 Val AUC Score: 0.3069
# Epoch [19/20] - Train Loss: 0.4520 Train AUC Score: 0.9795         Val Loss: 0.8284 Val AUC Score: 0.2946
# Epoch [20/20] - Train Loss: 0.4422 Train AUC Score: 0.9808         Val Loss: 0.8582 Val AUC Score: 0.2827
#
#  ----- Model 9 -----
# Epoch [1/20] - Train Loss: 0.8411 Train AUC Score: 0.4882         Val Loss: 0.6886 Val AUC Score: 0.5387
# Epoch [2/20] - Train Loss: 0.7204 Train AUC Score: 0.6919         Val Loss: 0.6640 Val AUC Score: 0.5580
# Epoch [3/20] - Train Loss: 0.6780 Train AUC Score: 0.7750         Val Loss: 0.6360 Val AUC Score: 0.6657
# Epoch [4/20] - Train Loss: 0.6230 Train AUC Score: 0.8580         Val Loss: 0.6248 Val AUC Score: 0.6083
# Epoch [5/20] - Train Loss: 0.6142 Train AUC Score: 0.8249         Val Loss: 0.6886 Val AUC Score: 0.5982
# Epoch [6/20] - Train Loss: 0.5662 Train AUC Score: 0.8902         Val Loss: 0.6357 Val AUC Score: 0.6640
# Epoch [7/20] - Train Loss: 0.5543 Train AUC Score: 0.8878         Val Loss: 0.5837 Val AUC Score: 0.7463
# Epoch [8/20] - Train Loss: 0.5489 Train AUC Score: 0.8870         Val Loss: 0.6414 Val AUC Score: 0.6414
# Epoch [9/20] - Train Loss: 0.5043 Train AUC Score: 0.9291         Val Loss: 0.6326 Val AUC Score: 0.5928
# Epoch [10/20] - Train Loss: 0.5007 Train AUC Score: 0.9366         Val Loss: 0.6770 Val AUC Score: 0.5737
# Epoch [11/20] - Train Loss: 0.4928 Train AUC Score: 0.8667         Val Loss: 0.6600 Val AUC Score: 0.6726
# Epoch [12/20] - Train Loss: 0.4653 Train AUC Score: 0.9299         Val Loss: 0.6570 Val AUC Score: 0.5796
# Epoch [13/20] - Train Loss: 0.4571 Train AUC Score: 0.9504         Val Loss: 0.6470 Val AUC Score: 0.6624
# Epoch [14/20] - Train Loss: 0.4562 Train AUC Score: 0.9544         Val Loss: 0.6295 Val AUC Score: 0.6667
# Epoch [15/20] - Train Loss: 0.4196 Train AUC Score: 0.9725         Val Loss: 0.6771 Val AUC Score: 0.5747
# Epoch [16/20] - Train Loss: 0.4140 Train AUC Score: 0.9816         Val Loss: 0.6751 Val AUC Score: 0.6608
# Epoch [17/20] - Train Loss: 0.4210 Train AUC Score: 0.9631         Val Loss: 0.5918 Val AUC Score: 0.7783
# Epoch [18/20] - Train Loss: 0.3997 Train AUC Score: 0.9841         Val Loss: 0.6480 Val AUC Score: 0.6378
# Epoch [19/20] - Train Loss: 0.4018 Train AUC Score: 0.9964         Val Loss: 0.6849 Val AUC Score: 0.6030
# Epoch [20/20] - Train Loss: 0.3835 Train AUC Score: 0.9396         Val Loss: 0.7095 Val AUC Score: 0.5738
#
#  ----- Model 10 -----
# Epoch [1/20] - Train Loss: 0.8465 Train AUC Score: 0.5177         Val Loss: 0.6770 Val AUC Score: 0.5401
# Epoch [2/20] - Train Loss: 0.7246 Train AUC Score: 0.7349         Val Loss: 0.6477 Val AUC Score: 0.5089
# Epoch [3/20] - Train Loss: 0.6665 Train AUC Score: 0.7676         Val Loss: 0.6274 Val AUC Score: 0.6817
# Epoch [4/20] - Train Loss: 0.6255 Train AUC Score: 0.8087         Val Loss: 0.6519 Val AUC Score: 0.6964
# Epoch [5/20] - Train Loss: 0.5920 Train AUC Score: 0.8590         Val Loss: 0.5784 Val AUC Score: 0.6406
# Epoch [6/20] - Train Loss: 0.5468 Train AUC Score: 0.8969         Val Loss: 0.6947 Val AUC Score: 0.6042
# Epoch [7/20] - Train Loss: 0.5411 Train AUC Score: 0.9165         Val Loss: 0.6998 Val AUC Score: 0.5722
# Epoch [8/20] - Train Loss: 0.5155 Train AUC Score: 0.9048         Val Loss: 0.6470 Val AUC Score: 0.6260
# Epoch [9/20] - Train Loss: 0.4985 Train AUC Score: 0.9409         Val Loss: 0.6423 Val AUC Score: 0.5660
# Epoch [10/20] - Train Loss: 0.4821 Train AUC Score: 0.9510         Val Loss: 0.7149 Val AUC Score: 0.5957
# Epoch [11/20] - Train Loss: 0.4701 Train AUC Score: 0.9639         Val Loss: 0.7148 Val AUC Score: 0.4866
# Epoch [12/20] - Train Loss: 0.4549 Train AUC Score: 0.9556         Val Loss: 0.6674 Val AUC Score: 0.6956
# Epoch [13/20] - Train Loss: 0.4353 Train AUC Score: 0.9674         Val Loss: 0.6494 Val AUC Score: 0.5953
# Epoch [14/20] - Train Loss: 0.4124 Train AUC Score: 0.9682         Val Loss: 0.7007 Val AUC Score: 0.6310
# Epoch [15/20] - Train Loss: 0.4150 Train AUC Score: 0.9709         Val Loss: 0.7318 Val AUC Score: 0.5569
# Epoch [16/20] - Train Loss: 0.4018 Train AUC Score: 0.9799         Val Loss: 0.7149 Val AUC Score: 0.5357
# Epoch [17/20] - Train Loss: 0.3928 Train AUC Score: 0.9903         Val Loss: 0.7593 Val AUC Score: 0.5978
# Epoch [18/20] - Train Loss: 0.3799 Train AUC Score: 0.9410         Val Loss: 0.7386 Val AUC Score: 0.5923
# Epoch [19/20] - Train Loss: 0.3653 Train AUC Score: 0.9906         Val Loss: 0.8074 Val AUC Score: 0.5456
# Epoch [20/20] - Train Loss: 0.3563 Train AUC Score: 0.9739         Val Loss: 0.6647 Val AUC Score: 0.7031

# %%
# After training all models, calculate the ensemble AUC

# Store predictions and labels
ensemble_predictions = []
val_labels = []
flag = 1

# Do not change gradients
with torch.no_grad():

    # Loop through each model
    for model, _ in ensemble_models:

        # Put model in evaluation mode
        model.eval()

        # Get predictions on the validation dataset
        predictions = []
        batch_labels = []  # Create a list to store labels for each batch

        for batch_x, batch_y in val_dl:

            batch_x_transformed = batch_x.unsqueeze(1)

            # Make predictions
            pred, _ = model(batch_x_transformed)
            # Save predictions
            predictions.append(pred)

            # Store val labels for this batch
            batch_labels.append(batch_y)

        # Concatenate the labels for this model
        if flag == 1:
            batch_labels = torch.cat(batch_labels, dim=0)
            val_labels.append(batch_labels)
            flag = 2

        predictions = torch.cat(predictions)
        ensemble_predictions.append(predictions)

# Concatenate all the validation labels
val_labels = torch.cat(val_labels, dim=0)

# Average the predictions from all models
ensemble_predictions = torch.stack(ensemble_predictions)
average_predictions = torch.mean(ensemble_predictions, dim=0)

# Calculate the AUC score based on the averaged predictions
average_auc = torchmetrics.AUROC(task="binary")(average_predictions, val_labels).item()
print(f"Ensemble AUC Score: {average_auc:.4f}")
# Out:
# Ensemble AUC Score: 0.5893

# %%
modified_chowder_decisive = pd.DataFrame({'predictions': average_predictions.squeeze(), 'true': val_labels})

decisive_path = '/content/drive/My Drive/Breast_Cancer_Detection/Decisive/'
modified_chowder_decisive.to_csv(decisive_path + 'modified_CHOWDER.csv', index=False)

# %%
sys.exit()

# %% [markdown]
# ## Test Model

# %%
## Setup DataLoaders

# Create a dummy y for test set
y_test_dummy = torch.zeros(len(X_test_tensor),)

# Create custom datasets
test_dataset = CustomDataset(X_test_tensor, y_test_dummy)

# Create DataLoader
test_dl = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False)

# Merge them using ConcatDataset
dev_dataset = ConcatDataset([train_dataset, val_dataset])

# Create a DataLoader for the merged dataset
dev_dl = DataLoader(dev_dataset, batch_size=BATCH_SIZE, shuffle=True, drop_last=True)

# %%
# Free Up Memory
del X_test_tensor
del train_dataset
del val_dataset

# %%
# Define loss function and optimizer
loss_function = nn.BCELoss()

# Create an ensemble of models
ensemble_models = []

for _ in range(NUM_ENSEMBLE_MODELS):

    # Initialize the model
    model = CHOWDER()

    # Define optimizer
    optimizer = optim.Adam(model.parameters(), lr=LR)
    ensemble_models.append((model, optimizer))

# Setup model counter
model_counter = 1

# Training loops for each model in the ensemble
for model, optimizer in ensemble_models:

    print(f'\n ----- Model {model_counter} -----')
    model_counter += 1

    # Loop thorugh each epoch
    for epoch in range(EPOCHS):

        ## Training loop

        # Put model in train mode
        model.train()

        # Initialize loss, AUC and count
        total_loss = 0.0
        auroc_hist_train = 0.0
        total_count = 0.0

        # Train in batches
        for batch_x, batch_y in dev_dl:

            # Add a dimension for channel numbers
            batch_x_transformed = batch_x.unsqueeze(1)

            # Zero gradients
            optimizer.zero_grad()

            # Make predictions and get L2-norm from conv layer
            pred, L2_term = model(batch_x_transformed)

            # Calculate loss
            batch_y = batch_y.view(-1, 1) # Reshape batch_y from (10) to (10,1)
            loss = loss_function(pred, batch_y) + (0.5*L2_term)

            # Calculate gradients
            loss.backward()

            # Make step in gradient descent
            optimizer.step()

            # Add to loss counter for this epoch
            total_loss += loss.item() * len(batch_y)
            total_count += len(batch_y)

            # Calculate AUC for batch
            auroc_hist_train += torchmetrics.AUROC(task="binary")(pred, batch_y).item() * len(batch_y)

        # Calculate loss and AUC per sample
        train_average_loss = total_loss / total_count
        train_average_auc = auroc_hist_train/ total_count

        # Print results from each epoch
        print(f"Epoch [{epoch+1}/{EPOCHS}] - Train Loss: {train_average_loss:.4f} Train AUC Score: {train_average_auc:.4f}")

# %%
# After training all models, calculate the ensemble AUC

# Store predictions and labels
ensemble_predictions = np.zeros((len(test_dataset), len(ensemble_models)))

# Do not change gradients
with torch.no_grad():

    model_counter = 0

    # Loop through each model
    for model, _ in ensemble_models:

        # Put model in evaluation mode
        model.eval()

        # Get predictions on the validation dataset
        predictions = np.empty((0, 1))

        for batch_x, _ in test_dl:

            extra = 10 - len(batch_x)

            # If batch size is smaller than 10, pad rows in batch_x with 0s
            if extra > 0:
                pad_tensor = torch.zeros((extra,) + batch_x.shape[1:], dtype=batch_x.dtype)
                batch_x = torch.cat((batch_x, pad_tensor), dim=0)

            # Add a dimension for channel numbers
            batch_x_transformed = batch_x.unsqueeze(1)

            # Make predictions
            pred, _ = model(batch_x_transformed)

            # Save predictions
            pred_numpy = pred.numpy()
            predictions = np.concatenate((predictions, pred_numpy), axis=0)

            if extra > 0:
              predictions = predictions[:-extra]

        ensemble_predictions[:, model_counter] = predictions.squeeze()
        model_counter += 1

# Average the predictions from all models
average_prediction = np.mean(ensemble_predictions, axis=1)

# %%
# Load metadata about each sample
data_path = '/content/drive/My Drive/Breast_Cancer_Detection/Data/'
df_test = pd.read_csv(data_path + "test_metadata.csv")

# Join sample ID metadata with probability prediction
CHOWDER_submission = pd.DataFrame( {"Sample ID": df_test["Sample ID"].values, "Target": average_prediction}).sort_values("Sample ID")

# %%
def sanity_checks(submission):
    assert all(submission["Target"].between(0, 1)), "`Target` values must be in [0, 1]"
    assert submission.shape == (149, 2), "Your submission file must be of shape (149, 2)"
    assert list(submission.columns) == ["Sample ID", "Target",], "Your submission file must have columns `Sample ID` and `Target`"

sanity_checks(CHOWDER_submission)

# %%
submission_path = '/content/drive/My Drive/Breast_Cancer_Detection/Predictions/'

CHOWDER_submission.to_csv(submission_path + "CHOWDER_submission_weights.csv", index=None)
